# %% [markdown]
# ## DATA CLEANING AND VISUALIZATION

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import os
import seaborn as sns

# %%
print(os.getcwd())
# Out:
# C:\Users\HP\Downloads

# %%
os.chdir('C:\\Users\\HP\\Downloads')

# %%
MetricsRatios_df = pd.read_csv(r"C:\Users\HP\Downloads\nasdaq100_metrics_ratios.csv")

# %%
MetricsRatios_df.head()
# Out:
#   symbol         company                  sector  \
# 0   AAPL      Apple Inc.  Information Technology
# 1   ABNB          Airbnb  Consumer Discretionary
# 2   ADBE      Adobe Inc.  Information Technology
# 3    ADI  Analog Devices  Information Technology
# 4    ADP             ADP  Information Technology
#
#                                     subsector  asset_turnover_2017  \
# 0  Technology Hardware, Storage & Peripherals                 0.66
# 1          Internet & Direct Marketing Retail                  NaN
# 2                        Application Software                 0.54
# 3                              Semiconductors                 0.36
# 4       Data Processing & Outsourced Services                  NaN
#
#    asset_turnover_2018  asset_turnover_2019  asset_turnover_2020  \
# 0                 0.72                 0.74                 0.83
# 1                 0.55                 0.64                 0.36
# ...

# %%
print(MetricsRatios_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Columns: 283 entries, symbol to yoy_revenue_growth_latest
# dtypes: float64(277), int64(2), object(4)
# memory usage: 225.6+ KB
# None

# %%
MetricsRatios_df["yoy_eps_growth_2022"].isnull().sum()
# Out:
# 77

# %%
# Filling null values
# with 0
MetricsRatios_df.fillna(value = 0,
          inplace = True)
 
# Show the DataFrame
print(MetricsRatios_df)
# Out:
#     symbol                    company                  sector  \
# 0     AAPL                 Apple Inc.  Information Technology
# 1     ABNB                     Airbnb  Consumer Discretionary
# 2     ADBE                 Adobe Inc.  Information Technology
# 3      ADI             Analog Devices  Information Technology
# 4      ADP                        ADP  Information Technology
# ..     ...                        ...                     ...
# 97     WBA   Walgreens Boots Alliance        Consumer Staples
# 98    WDAY              Workday, Inc.  Information Technology
# 99     XEL                Xcel Energy               Utilities
# 100     ZM  Zoom Video Communications  Information Technology
# 101     ZS                    Zscaler  Information Technology
#
#                                       subsector  asset_turnover_2017  \
# 0    Technology Hardware, Storage & Peripherals                 0.66
# 1            Internet & Direct Marketing Retail                 0.00
# ...

# %%
MetricsRatios_df.describe()
# Out:
#        asset_turnover_2017  asset_turnover_2018  asset_turnover_2019  \
# count           102.000000           102.000000           102.000000
# mean              0.518824             0.731765             0.708824
# std               0.554578             0.526275             0.509994
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.422500             0.402500
# 50%               0.430000             0.600000             0.580000
# 75%               0.717500             0.877500             0.807500
# max               3.710000             3.670000             3.540000
#
#        asset_turnover_2020  asset_turnover_2021  asset_turnover_2022  \
# count           102.000000           102.000000           102.000000
# mean              0.647353             0.675980             0.171863
# std               0.459972             0.440727             0.336295
# ...

# %%
MetricsRatios_df['company'].max()
# Out:
# 'eBay'

# %%
plt.figure(figsize=(12,6))    # Types of sectors and the topmost sector amongst all companies.
data = MetricsRatios_df.sector.value_counts()
sns.barplot(y = data.index, x = data, orient='h')
plt.show()

# %%
plt.figure(figsize=(12,6))     # Types of subsectors and the topmost subsector amongst all companies.
sns.countplot(x='subsector', data=MetricsRatios_df)
plt.xticks(rotation='vertical')
plt.show()

# %%
data = MetricsRatios_df.sector.value_counts()  # sector percentage


labels = (np.array(data.index))
sizes = (np.array((data / data.sum())*100))
colors = ['red', 'lightskyblue','pink','yellow','orange','green','silver']
plt.pie(sizes, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("sector percentage")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.histplot(MetricsRatios_df['sector'], kde=True)

plt.title('Distribution of Sectors')
plt.xlabel('Sector')
plt.ylabel('count')

plt.show()

# %% [markdown]
# ### INSIGHTS

# %% [markdown]
# Here we performed Exploratory Data Analysis of the finace metrics dataset in which there are some plots which are showing sector, subsectorwise distribution in the companies, Asset turnover of the topmost company and also the relation between asset turnover and year over year growth revenue of the topmost company.
